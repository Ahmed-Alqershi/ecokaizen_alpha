# %%
import sqlite3
import pandas as pd

# Connect to the database
conn = sqlite3.connect('users.db')

# Get the list of tables
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print("Tables in users.db:")
print(tables)

# Optionally, show the contents of each table
for table_name in tables['name']:
    print(f"\nContents of table '{table_name}':")
    df = pd.read_sql_query(f"SELECT * FROM {table_name};", conn)
    display(df)

conn.close()
# Out:
# Tables in users.db:
#               name
# 0            users
# 1  sqlite_sequence
#
# Contents of table 'users':
#    id username                                           password
# 0   1    Ahmed  scrypt:32768:8:1$I9024xAJ93wrmW6w$9858ed054ec3...
# 1   2   AlMaan  scrypt:32768:8:1$QvGfWClRQovK45De$b3515604656e...
# Contents of table 'sqlite_sequence':
#     name  seq
# 0  users    2
